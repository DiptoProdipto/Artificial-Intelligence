# %%
import csv

# %%
with open('starbucks.csv','r') as csv_file:
    csv_reader = csv.reader(csv_file)
    
    #next(csv_reader)
    
    for line in csv_reader:
        print(line[0])
# Out:
# ï»¿Brand
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# Starbucks
# ...
